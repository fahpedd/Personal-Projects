# %%
#https://www.kaggle.com/kanncaa1/plotly-tutorial-for-beginners
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# plotly
import plotly.plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
# matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
#iplot([{"x": [1, 2, 3], "y": [3, 1, 6]}])
df = pd.read_csv("uk_econcomic.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 91 columns):
# Unnamed: 0                                                                             45 non-null int64
# Year                                                                                   45 non-null int64
# GDP (current US$)                                                                      45 non-null float64
# GDP per capita (current US$)                                                           45 non-null float64
# GDP growth (annual %)                                                                  45 non-null float64
# GDP per capita growth (annual %)                                                       45 non-null float64
# Inflation, GDP deflator (annual %)                                                     45 non-null float64
# Consumer price index (2010 = 100)                                                      45 non-null float64
# Tax revenue (% of GDP)                                                                 44 non-null float64
# Rural population                                                                       45 non-null float64
# Rural population (% of total population)                                               45 non-null float64
# Rural population growth (annual %)                                                     45 non-null float64
# Urban population                                                                       45 non-null float64
# Urban population (% of total)                                                          45 non-null float64
# Urban population growth (annual %)                                                     45 non-null float64
# Employment to population ratio, 15+, female (%) (national estimate)                    38 non-null float64
# Employment to population ratio, 15+, male (%) (national estimate)                      38 non-null float64
# Employment to population ratio, 15+, total (%) (national estimate)                     38 non-null float64
# Employment to population ratio, ages 15-24, female (%) (national estimate)             35 non-null float64
# Employment to population ratio, ages 15-24, male (%) (national estimate)               35 non-null float64
# Employment to population ratio, ages 15-24, total (%) (national estimate)              35 non-null float64
# Ratio of female to male labor force participation rate (%) (national estimate)         39 non-null float64
# Part time employment, female (% of total female employment)                            35 non-null float64
# Part time employment, male (% of total male employment)                                35 non-null float64
# Part time employment, total (% of total employment)                                    35 non-null float64
# Unemployment, youth female (% of female labor force ages 15-24) (national estimate)    35 non-null float64
# Unemployment, youth male (% of male labor force ages 15-24) (national estimate)        35 non-null float64
# Unemployment, youth total (% of total labor force ages 15-24) (national estimate)      35 non-null float64
# Birth rate, crude (per 1,000 people)                                                   44 non-null float64
# Death rate, crude (per 1,000 people)                                                   44 non-null float64
# Life expectancy at birth, female (years)                                               44 non-null float64
# Life expectancy at birth, male (years)                                                 44 non-null float64
# Life expectancy at birth, total (years)                                                44 non-null float64
# Population growth (annual %)                                                           45 non-null float64
# Population, female                                                                     45 non-null float64
# Population, female (% of total)                                                        45 non-null float64
# Population, male                                                                       45 non-null float64
# Population, male (% of total)                                                          45 non-null float64
# Population, total                                                                      45 non-null float64
# Merchandise exports (current US$)                                                      45 non-null float64
# Merchandise imports (current US$)                                                      45 non-null float64
# Exports of goods and services (% of GDP)                                               45 non-null float64
# Exports of goods and services (annual % growth)                                        45 non-null float64
# Exports of goods and services (current US$)                                            45 non-null float64
# Imports of goods and services (% of GDP)                                               45 non-null float64
# Imports of goods and services (annual % growth)                                        45 non-null float64
# Imports of goods and services (current US$)                                            45 non-null float64
# Agricultural raw materials exports (% of merchandise exports)                          45 non-null float64
# Agricultural raw materials imports (% of merchandise imports)                          45 non-null float64
# Food exports (% of merchandise exports)                                                45 non-null float64
# Food imports (% of merchandise imports)                                                45 non-null float64
# Fuel exports (% of merchandise exports)                                                45 non-null float64
# Fuel imports (% of merchandise imports)                                                45 non-null float64
# Ores and metals exports (% of merchandise exports)                                     45 non-null float64
# Ores and metals imports (% of merchandise imports)                                     45 non-null float64
# Manufactures exports (% of merchandise exports)                                        45 non-null float64
# Manufactures imports (% of merchandise imports)                                        45 non-null float64
# Computer, communications and other services (% of commercial service exports)          45 non-null float64
# Computer, communications and other services (% of commercial service imports)          45 non-null float64
# Insurance and financial services (% of commercial service exports)                     43 non-null float64
# Insurance and financial services (% of commercial service imports)                     43 non-null float64
# Transport services (% of commercial service exports)                                   45 non-null float64
# Transport services (% of commercial service imports)                                   45 non-null float64
# Travel services (% of commercial service exports)                                      45 non-null float64
# Travel services (% of commercial service imports)                                      45 non-null float64
# Trade (% of GDP)                                                                       45 non-null float64
# Trade in services (% of GDP)                                                           45 non-null float64
# School enrollment, primary (% gross)                                                   38 non-null float64
# School enrollment, primary (% net)                                                     38 non-null float64
# School enrollment, primary (gross), gender parity index (GPI)                          38 non-null float64
# School enrollment, primary and secondary (gross), gender parity index (GPI)            38 non-null float64
# School enrollment, primary, female (% gross)                                           38 non-null float64
# School enrollment, primary, male (% gross)                                             38 non-null float64
# School enrollment, secondary (% gross)                                                 43 non-null float64
# School enrollment, secondary (% net)                                                   39 non-null float64
# School enrollment, secondary (gross), gender parity index (GPI)                        43 non-null float64
# School enrollment, secondary, female (% gross)                                         43 non-null float64
# School enrollment, secondary, female (% net)                                           39 non-null float64
# School enrollment, secondary, male (% gross)                                           43 non-null float64
# School enrollment, secondary, male (% net)                                             39 non-null float64
# School enrollment, tertiary (% gross)                                                  43 non-null float64
# School enrollment, tertiary (gross), gender parity index (GPI)                         43 non-null float64
# School enrollment, tertiary, female (% gross)                                          43 non-null float64
# School enrollment, tertiary, male (% gross)                                            43 non-null float64
# Secondary education, duration (years)                                                  45 non-null float64
# Secondary education, general pupils                                                    43 non-null float64
# Secondary education, general pupils (% female)                                         43 non-null float64
# Secondary education, pupils                                                            43 non-null float64
# Secondary education, pupils (% female)                                                 43 non-null float64
# Secondary education, vocational pupils                                                 43 non-null float64
# Secondary education, vocational pupils (% female)                                      43 non-null float64
# dtypes: float64(89), int64(2)
# memory usage: 32.1 KB

# %%
# import graph objects as "go"
import plotly.graph_objs as go

# Creating trace1
trace1 = go.Scatter(
                    x = df['Year'],
                    y = df['GDP growth (annual %)'],
                    mode = "lines+markers",
                    name = "GDP growth (annual %)",
                    marker = dict(color = 'rgba(16, 112, 2, 0.8)')
                    )
# Creating trace2
trace2 = go.Scatter(
                    x = df['Year'],
                    y = df['Population growth (annual %)'],
                    mode = "lines+markers",
                    name = "Population growth (annual %)",
                    marker = dict(color = 'rgba(80, 26, 80, 0.8)')
                    )
data = [trace1, trace2]
layout = dict(title = 'Annual GDP growth and Population Since Joining The EU',
              xaxis= dict(title= 'Year',ticklen= 5,zeroline= False),
              yaxis= dict(title= 'Percentage',ticklen= 5,zeroline= True)
             )
fig = dict(data = data, layout = layout)
iplot(fig)
# Out:
# <div id="233ab238-504a-4a6b-84f7-2c0456cdf962" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot
}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# import graph objects as "go"
import plotly.graph_objs as go

# Creating trace1
trace1 = go.Scatter(
                    x = df['Year'],
                    y = df['Merchandise exports (current US$)'],
                    mode = "lines",
                    name = "Merchandise exports",
                    marker = dict(color = 'rgba(16, 112, 2, 0.8)')
                    )
# Creating trace2
trace2 = go.Scatter(
                    x = df['Year'],
                    y = df['Merchandise imports (current US$)'],
                    mode = "lines",
                    name = "Merchandise imports",
                    marker = dict(color = 'rgba(80, 26, 80, 0.8)')
                    )
data = [trace1, trace2]
layout = dict(title = 'Merchandise Exports Vs Merchandise Imports',
              xaxis= dict(title= 'Year',ticklen= 5,zeroline= False),
              yaxis= dict(title= 'current US$',ticklen= 5,zeroline= True)
             )
fig = dict(data = data, layout = layout)
iplot(fig)
# Out:
# <div id="9b1ce0f8-c4a2-44ff-b163-0d4e0fb999e3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9b1ce0f8-c4a2-44ff-b163-0d4e0fb999e3", [{"marker": {"color": "rgba(16, 112, 2, 0.8)"}, "mode": "lines", "name": "Merchandise exports", "x": [1973.0, 1974.0, 1975.0, 1976.0, 1977.0, 1978.0, 1979.0, 1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0], "y": [29637300000.0, 38196600000.0, 43422900000.0, 45355500000.0, 55859900000.0, 67886600000.0, 86396900000.0, 110134000000.0, 102244000000.0, 96984000000.0, 91619000000.0, 93881000000.0, 101252000000.0, 107093000000.0, 131257000000.0, 145165000000.0, 152345000000.0, 185172000000.0, 184964000000.0, 190003000000.0, 181381000000.0, 205079000000.0, 237953000000.0, 258527000000.0, 280406000000.0, 273949000000.0, 272166557653.0, 285425264505.0, 272715187874.0, 280195147574.0, 305627051282.0, 347493474259.0, 390859987627.993, 450907024800.572, 441830822019.367, 472167687885.443, 354893022576.954, 415958982008.248, 506570012060.208, 472791881760.0, 540615854760.0, 505204769850.0, 460153475250.0, 409578348010.0, 444981599920.0], "type": "scatter", "uid": "256001f4-ed35-11e8-9362-a8a795145588"}, {"marker": {"color": "rgba(80, 26, 80, 0.8)"}, "mode": "lines", "name": "Merchandise imports", "x": [1973.0, 1974.0, 1975.0, 1976.0, 1977.0, 1978.0, 1979.0, 1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0], "y": [38528100000.0, 54190300000.0, 53340900000.0, 55743600000.0, 63191300000.0, 75813000000.0, 99599800000.0, 115545000000.0, 102708000000.0, 99646000000.0, 100080000000.0, 104725000000.0, 108957000000.0, 126330000000.0, 154407000000.0, 189340000000.0, 197731000000.0, 222977000000.0, 209947000000.0, 221551000000.0, 209318000000.0, 234076000000.0, 267250000000.0, 287332000000.0, 307518000000.0, 321231000000.0, 324899403477.0, 348057557314.0, 343785506789.0, 364074754539.0, 399401428268.0, 470632528734.0, 519273236616.414, 612671005570.301, 638262575389.501, 657782671791.3721, 519078080941.974, 591094912207.81, 676895684806.704, 695220440640.0, 660034489650.0, 690466087600.0, 626369334500.0, 636365886580.0, 644055074520.0], "type": "scatter", "uid": "256001f5-ed35-11e8-b272-a8a795145588"}], {"title": "Merchandise Exports Vs Merchandise Imports", "xaxis": {"ticklen": 5, "title": "Year", "zeroline": false}, "yaxis": {"ticklen": 5, "title": "current US$", "zeroline": true}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
